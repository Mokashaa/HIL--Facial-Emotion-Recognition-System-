# %% [markdown]
# This is a script to :
# 1. connect to google drive
# 2. install kaggle to use datasets download APIs
# 3. download fer2013 dataset
#
# Google account:
#
# 1. Username: aaosm2020@gmail.com
# 2. Password: aaosm2020aaosm
#
# Note:
# kaggle.json file is required for datasets download.
#
# Visit www.kaggle.com ⇨ login ⇨ My Account ⇨ Create New API Token
# and the file will be downloaded automatically
#
# check this link:
# https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from google.colab import files
files.upload()  #this will prompt you to upload the kaggle.json

# %%
# !pip install -q kaggle --upgrade
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json  # set permission

# %%
# !kaggle competitions download -c challenges-in-representation-learning-facial-expression-recognition-challenge
